# %%
from datetime import datetime
import os

from dateutil import parser
from dateutil.relativedelta import relativedelta
import pandas as pd

# %%
MUSEUMS_DATABASE_FILENAME = os.path.expanduser('~/Documents/Museums Database.xlsx')

# %%
CORRECTIONS = {
    "Alexandre Estrela--February 19-May 8, Vaast Colson & Kati Heck--February 19-May 29":
        "Alexandre Estrela--February 19-May 8; Vaast Colson & Kati Heck--February 19-May 29",
    "João Maria Gusmão & Pedro Paiva-Apr 30-Jul 31":
        "João Maria Gusmão & Pedro Paiva--Apr 30-Jul 31",
    "Yngve Holen-May 13-Aug 7":
        "Yngve Holen--May 13-Aug 7",
    "Manifesta 11-Jun 6-Sept 18":
        "Manifesta 11--Jun 6-Sept 18",
    "Pipilotti Rist Feb-May 8":
        "Pipilotti Rist--Feb-May 8",
    "Esma'/Listen (Lawrence Abu Hamdan etc.) until 21 Aug.":
        "Esma'/Listen (Lawrence Abu Hamdan etc.)--Apr 01-Aug 21",
    "Question the Wall Itself==Nov 19-Mar 26":
        "Question the Wall Itself--Nov 19-Mar 26",
    "Basquiat:\nThe Unknown Notebooks\nFeb 28-May 29":
        "Basquiat: The Unknown Notebooks--Feb 28-May 29",
    "Come As You Are: Art of the 1990s\nFebruary 21 – May 15":
        "Come As You Are: Art of the 1990s--February 21 – May 15",
    "\nDavid Tartakover":
        "David Tartakover",
    "Dan Colen, Helmut Lang, Paola Pivi --Apr 16-Aug\n16 APRIL - AUGUST 2016":
        "Dan Colen, Helmut Lang, Paola Pivi --Apr 16-Aug 31",
    " Rodney\nMcMillian--Mar 24-?":
        "Rodney McMillian--Mar 24-Mar 31",
    "Everything in nature has a lyrical essence, a tragic fate, a comic existence---January 28-March 5":
        "Everything in nature has a lyrical essence, a tragic fate, a comic existence--January 28-March 5",
    "Dominique Gonzalez--Foerster-Apr 23-Aug 7":
        "Dominique Gonzalez-Foerster--Apr 23-Aug 7",
    "Kanon-Fragen-Past Disquiet--March":
        "Kanon-Fragen-Past Disquiet",
    "Kerstin Brätsch--mid-Feb-late May":
        "Kerstin Brätsch--Feb 14-May 31",
    "Fade In--Int. Art Day":
        "Fade In - Int. Art Day",
    "Catherine Opie: Portraits--Jan 30":
        "Catherine Opie: Portraits--Jan 30-Jan 30",
    "Festival of Political Photography--February 19 – May 1":
        "Festival of Political Photography--February 19 - May 1",
    "Come As You Are: Art of the 1990s--February 21 – May 15":
        "Come As You Are: Art of the 1990s--February 21 - May 15",
    "Art Basel Hong Kong--March 24-26, 2016":
        "Art Basel Hong Kong--March 24-Mar 26",
    "Routine Pleasures--May 26-Aug 14 (in LA)":
        "Routine Pleasures--May 26-Aug 14",
    "Cy Twombly--May ?-Feb ?":
        "Cy Twombly--May 15-Feb 14",
    "Alice Neel--Nov 5-?":
        "Alice Neel--Nov 5-Nov 30",
    "Francesca Woodman--Sept 6-Dec ?":
        "Francesca Woodman--Sept 6-Dec 15",
}

# %%
non_us_museum_shows = pd.read_excel(MUSEUMS_DATABASE_FILENAME, sheetname="Non-US")
us_museum_shows = pd.read_excel(MUSEUMS_DATABASE_FILENAME, sheetname="US")

# %%
museums = []
shows = []

# %%
def add_show(museum_name, column_date, show_details):
    if show_details in CORRECTIONS:
        show_details = CORRECTIONS[show_details]

    if '--' in show_details:
        show_name, show_dates = show_details.split('--')
        show_name = show_name.strip()

        start_date_string, end_date_string = show_dates.split('-')
        start_date = parser.parse(
            start_date_string.strip(), default=column_date,
        )
        end_date = parser.parse(
            end_date_string.strip(), default=start_date,
        )
        
        while end_date < start_date:
            end_date += relativedelta(years=1)
    else:
        # No further date details for this show. Use the column header.
        show_name = show_details
        start_date = column_date
        end_date = column_date + relativedelta(months=1, days=-1)

    shows.append({
        'museum_name': museum_name,
        'name': show_name,
        'start_date': start_date,
        'end_date': end_date,
    })

# %%
def process_museum_shows(museum_shows):
    for _, row in museum_shows.iterrows():
        museum_name = row.Name

        museums.append({
            'name': museum_name,
            'region': row.Region,
            'country': row.Country,
            'city': row.City
        })

        for key, value in row.iteritems():
            # These aren't the actual shows.
            if key in ('Notes', 'Name', 'Region', 'Country', 'City'):
                continue

            if value != value or value == '?':
                continue

            # It's silly to parse this for every row, but it doesn't matter.
            column_month, column_year = key.split(' \'')
            column_date = parser.parse(
                column_month,
                default=datetime(2000 + int(column_year), 1, 1),
            )
            
            if value in CORRECTIONS:
                value = CORRECTIONS[value]
            
            for show_details in value.split('; '):
                add_show(museum_name, column_date, show_details)

# %%
process_museum_shows(non_us_museum_shows)
process_museum_shows(us_museum_shows)

# %%
pd.DataFrame(museums, columns=('name', 'region', 'country', 'city'))
# Out:
#                                           name       region      country  \
# 0                 National Art Museum of China      E. Asia        China
# 1        Kunstsammlung Nordrhein-Westfalen K20       Europe      Germany
# 2                  Museum der Moderne Salzburg       Europe      Austria
# 3                        Royal Academy of Arts       Europe           UK
# 4                                  Tate Modern       Europe           UK
# 5                             Tallinn Art Hall       Europe      Estonia
# 6                       Art Gallery of Ontario   N. America       Canada
# 7                               Haus der Kunst       Europe      Germany
# 8                            The Israel Museum  Middle East       Israel
# 9                 National Gallery of Scotland       Europe           UK
# 10                                         WUK       Europe      Austria
# 11                             Pompidou Malaga       Europe        Spain
# 12                             Van Gogh Museum       Europe  Netherlands
# 13                                   Secession       Europe      Austria
# 14                           Kunsthaus Bregenz       Europe      Austria
# 15                            Mudam Luxembourg       Europe   Luxembourg
# 16                        Faurschou Foundation      E. Asia        China
# 17                                 Long Museum      E. Asia        China
# 18                         Minsheng Art Museum      E. Asia        China
# 19                    National Museum of China      E. Asia        China
# 20                         Rockbund Art Museum      E. Asia        China
# 21          Ullens Center for Contemporary Art      E. Asia        China
# 22                                Asia Society      E. Asia        China
# 23                M+ Museum for Visual Culture      E. Asia        China
# 24   Hiroshima City Museum of Contemporary Art      E. Asia        Japan
# 25       The Watari Museum of Contemporary Art      E. Asia        Japan
# 26     21st Century Museum of Contemporary Art      E. Asia        Japan
# 27                National Museum of Art Osaka      E. Asia        Japan
# 28             Hara Museum of Contemporary Art      E. Asia        Japan
# 29                             Mori Art Museum      E. Asia        Japan
# ..                                         ...          ...          ...
# 263                   Rubell Family Collection   N. America          USA
# 264              Minneapolis Institute of Arts   N. America          USA
# 265                Yale University Art Gallery   N. America          USA
# 266                               Asia Society   N. America          USA
# 267                            Brooklyn Museum   N. America          USA
# 268                                 Dia Center   N. America          USA
# 269                              Fisher Landau   N. America          USA
# 270                                        ICP   N. America          USA
# 271                              Jewish Museum   N. America          USA
# 272                 Metropolitan Museum of Art   N. America          USA
# 273                                       MoMA   N. America          USA
# 274                                   MoMA PS1   N. America          USA
# 275                             Morgan Library   N. America          USA
# 276                               Neue Galerie   N. America          USA
# 277                         Park Avenue Armory   N. America          USA
# 278                              Studio Museum   N. America          USA
# 279                         The Drawing Center   N. America          USA
# 280                                The Kitchen   N. America          USA
# 281                       The Sculpture Center   N. America          USA
# 282                             Whitney Museum   N. America          USA
# 283                          Barnes Foundation   N. America          USA
# 284                                   Carnegie   N. America          USA
# 285                Princeton University Museum   N. America          USA
# 286               Virginia Museum of Fine Arts   N. America          USA
# 287                  Saint Louis Museum of Art   N. America          USA
# 288                                   De Young   N. America          USA
# 289                                     SFMOMA   N. America          USA
# 290                         Seattle Art Museum   N. America          USA
# 291                                 Hirshhorn    N. America          USA
# 292                           National Gallery   N. America          USA
#
#               city
# 0          Beijing
# 1       Düsseldorf
# 2          Salzbug
# 3           London
# 4           London
# 5          Tallinn
# 6          Toronto
# 7           Munich
# 8        Jerusalem
# 9        Edinburgh
# 10          Vienna
# 11          Malaga
# 12       Amsterdam
# 13          Vienna
# 14         Bregenz
# 15      Luxembourg
# 16         Beijing
# 17        Shanghai
# 18        Shanghai
# 19         Beijing
# 20        Shanghai
# 21         Beijing
# 22       Hong Kong
# 23       Hong Kong
# 24       Hiroshima
# 25           Tokyo
# 26        Kanazawa
# 27           Osaka
# 28           Tokyo
# 29           Tokyo
# ..             ...
# 263          Miami
# 264    Minneapolis
# 265      New Haven
# 266       New York
# 267       New York
# 268       New York
# 269       New York
# 270       New York
# 271       New York
# 272       New York
# 273       New York
# 274       New York
# 275       New York
# 276       New York
# 277       New York
# 278       New York
# 279       New York
# 280       New York
# 281       New York
# 282       New York
# 283   Philadelphia
# 284     Pittsburgh
# 285      Princeton
# 286       Richmond
# 287    Saint Louis
# 288  San Francisco
# 289  San Francisco
# 290        Seattle
# 291     Washington
# 292     Washington
#
# [293 rows x 4 columns]

# %%
pd.DataFrame(shows, columns=('museum_name', 'name', 'start_date', 'end_date'))
# Out:
#                                museum_name  \
# 0    Kunstsammlung Nordrhein-Westfalen K20
# 1    Kunstsammlung Nordrhein-Westfalen K20
# 2    Kunstsammlung Nordrhein-Westfalen K20
# 3              Museum der Moderne Salzburg
# 4              Museum der Moderne Salzburg
# 5                    Royal Academy of Arts
# 6                    Royal Academy of Arts
# 7                    Royal Academy of Arts
# 8                              Tate Modern
# 9                              Tate Modern
# 10                             Tate Modern
# 11                             Tate Modern
# 12                             Tate Modern
# 13                        Tallinn Art Hall
# 14                        Tallinn Art Hall
# 15                        Tallinn Art Hall
# 16                  Art Gallery of Ontario
# 17                  Art Gallery of Ontario
# 18                          Haus der Kunst
# 19                          Haus der Kunst
# 20                       The Israel Museum
# 21                       The Israel Museum
# 22                       The Israel Museum
# 23            National Gallery of Scotland
# 24            National Gallery of Scotland
# 25            National Gallery of Scotland
# 26                                     WUK
# 27                                     WUK
# 28                                     WUK
# 29                                     WUK
# ..                                     ...
# 395                                  LACMA
# 396                                   MOCA
# 397                                   MOCA
# 398          Institute of Contemporary Art
# 399          Institute of Contemporary Art
# 400          Institute of Contemporary Art
# 401          Institute of Contemporary Art
# 402          Institute of Contemporary Art
# 403          Institute of Contemporary Art
# 404                           Perez Museum
# 405                           Perez Museum
# 406          Minneapolis Institute of Arts
# 407                           Asia Society
# 408                        Brooklyn Museum
# 409             Metropolitan Museum of Art
# 410             Metropolitan Museum of Art
# 411                                   MoMA
# 412                                   MoMA
# 413                     Park Avenue Armory
# 414                     Park Avenue Armory
# 415                          Studio Museum
# 416                          Studio Museum
# 417                   The Sculpture Center
# 418                         Whitney Museum
# 419                         Whitney Museum
# 420                      Barnes Foundation
# 421                               Carnegie
# 422                               De Young
# 423                     Seattle Art Museum
# 424                             Hirshhorn
#
#                                                   name start_date   end_date
# 0                                     Cyprien Gaillard 2016-01-30 2016-03-20
# 1                          Dominique Gonzalez-Foerster 2016-04-23 2016-08-07
# 2                                       Andreas Gursky 2016-07-02 2016-11-06
# 3                                         Affichomanie 2016-03-12 2016-07-10
# 4                              Anti: Modern - Salzburg 2016-07-01 2016-07-31
# 5                                   Ann Christopher RA 2016-02-05 2016-05-29
# 6                             David Hockney (new work) 2016-07-02 2016-10-02
# 7                   James Ensor curated by Luc Tuymans 2016-10-29 2017-01-29
# 8                                          Mona Hatoum 2016-05-04 2016-08-21
# 9                                       Bhupen Khakhar 2016-06-01 2016-11-06
# 10                                     Georgia O'Keefe 2016-07-06 2016-10-30
# 11                                        Wilfredo Lam 2016-09-14 2017-01-08
# 12                                 Robert Rauschenberg 2016-12-01 2017-04-02
# 13                                           Idealists 2016-07-02 2016-08-14
# 14                                   Silence, Darkness 2016-08-27 2016-10-09
